# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def psi(n,x):
    N = np.zeros(n+1)
    N[n] = 1
    H = np.polynomial.hermite.Hermite(N)
    Norm = 2**(-0.5 * n) * np.pi**-0.25 * (np.math.factorial(n))**-0.5 
    wf = Norm * np.exp(-x**2/2) * H(x)
    return wf

class Solver_Herm:
    def __init__(self,L1,L2,h,n_herm,V,T):
        self.L1 = L1
        self.L2 = L2
        self.h = h
        self.N = int((L2-L1) / h)
        self.V = V
        self.T = T
        self.n_herm = n_herm
        self.x = np.arange(L1,L2,h)
        self.p=(2*np.pi/self.h) * np.fft.fftfreq(self.x.shape[0])
        self.H = np.zeros((self.n_herm,self.n_herm))
        self.values = np.zeros((self.n_herm))
        self.vectors_herm = np.zeros((self.n_herm,self.n_herm))
        self.vectors_x = np.zeros((self.n_herm,self.N))
        self.vectors_p = np.zeros((self.n_herm,self.N))
        self.PSI = np.array([psi(n,self.x) for n in range(self.n_herm)])
        
    def op_H(self,F_x):
        F_p = np.fft.fft(F_x)
        p = (2*np.pi/self.h) * np.fft.fftfreq(F_x.shape[0])
        TF_p = self.T(p) * F_p
        TF_x = np.fft.ifft(TF_p).real
        HF=TF_x + self.V(self.x) * F_x
        return HF
        
    
    def compute_H(self):
        I=np.eye(self.n_herm)
        for i in range(self.n_herm):
            for j in range(self.n_herm):
                self.H[i][j] = self.h * np.dot(self.PSI[i],self.op_H(self.PSI[j]))
        return self
    
    def compute_eigen(self):
        E = np.linalg.eigh(self.H)
        self.values = E[0]
        self.vectors_herm = np.transpose(E[1])
        return self
    
    def x_rep(self):
        self.vectors_x = np.dot(self.vectors_herm,self.PSI)
        return self
    
    def p_rep(self):
        PSI_p = self.h *(2*np.pi)**-0.5 * np.fft.fft(self.PSI,axis=1)
        self.vectors_p = np.dot(self.vectors_herm,PSI_p)
        return self
        
    def compute_all(self):
        self.compute_H().compute_eigen().x_rep().p_rep()
        return self
    
    def mean_x(self,f,n=0):
        F = f(self.x)
        psi_x = self.vectors_x[n]
        return self.h * np.dot(psi_x**2,F)
    
    def mean_p(self,f,n=0):
        F = f(self.p)
        psi_p = self.vectors_p[n]
        return (2*np.pi/(self.L2-self.L1)) * np.dot(np.abs(psi_p)**2,F)
    
    def get_rho(self,beta):
        E = np.exp(-beta*(self.values-self.values[0]))
        rho = np.dot(E,self.vectors_x**2)/np.sum(E)
        return rho
    
    def log_Z(self,beta):
        return np.log(np.sum(np.exp(-beta*self.values)))
    
    def plot(self,n):
        fig=plt.figure()
        plt.grid(True)
        plt.plot(self.x,self.vectors_x[n])
        plt.show()

# %%
def T(p):
    return p**2/2

def T_rel(p):
    return (1+p**2)**0.5-1

def T_ur(p):
    return np.abs(p)

# %%
def x2(x):
    return x**2

# %%
def V_osc(x):
    return x**2 / 2

# %%
def one(x):
    return np.ones((x.shape[0]))

# %%
solv = Solver_Herm(-10,10,0.01,30,V_osc,T_ur)
solv.compute_all()
plt.figure()
plt.grid(True)
plt.plot(solv.x,solv.vectors_x[0]**2)
plt.plot(solv.x,solv.get_rho(16))
plt.legend([r"$|\psi(x)|^2$",r"$\rho(x,x) \quad \beta=16$"])
plt.show()
print("<x^2>=",solv.mean_x(x2))
print("<T>=",solv.mean_p(T_rel))
print("<V>=",solv.mean_x(V_osc))
print(-solv.log_Z(16))
# Out:
# <x^2>= 0.546178422752784
# <T>= 0.18669551811507953
# <V>= 0.273089211376392
# 12.772259755335824

# %%
y=np.zeros((2,solv.N))
y[0]=solv.vectors_x[0]**2
y[1]=solv.x
np.savetxt("relpsi2.txt",y)

# %%
from math import gamma
def get_V_morse(alpha):
    def V_morse(x):
        y = np.exp(-alpha * x)-1
        return 0.5*(y**2-1)
    return V_morse

def theor_Psi2(alpha,x):
        N = 2**(2 / alpha - 1) * (2-alpha)/( (alpha ** (2/alpha - 1)) * gamma(2/alpha))
        power = (-2 / alpha) * np.exp(-alpha * x) - (2-alpha) * x
        P=N*np.exp(power)
        return P

# %%
alpha=0.125
V=get_V_morse(alpha)
solv = Solver_Herm(-20,20,0.01,30,V,T)
solv.compute_all()

plt.figure()
plt.grid(True)
plt.plot(solv.x,solv.vectors_x[0]**2)
plt.plot(solv.x,solv.get_rho(32))
plt.plot(solv.x,theor_Psi2(alpha,solv.x))
plt.legend([r"$|\psi(x)|^2$",r"$\rho(x,x) \quad \beta=32$",r"$|\psi|^2_{nonrel}$"])
plt.show()

print("<x^2>=",solv.mean_x(x2))
print("<T>=",solv.mean_p(T_rel))
print("<V>=",solv.mean_x(V))
print(-solv.log_Z(16))
# Out:
# <x^2>= 4.499972350347425
# <T>= 0.030482367290533913
# <V>= -0.4704628228331809
# -7.162911814754144

# %%
y=np.zeros((2,solv.N))
y[0]=solv.vectors_x[0]**2
y[1]=solv.x
np.savetxt("relmorsepsi2.txt",y)

# %% [markdown]
# Число дискретных уровней
# $N(\alpha)=[\frac{2-\alpha}{2\alpha}]+1$
#
#
# $N(1)=1 \qquad N(0.5)=2 \qquad N(0.125)=8$

# %%
alpha = 0.5
V=get_V_morse(alpha)
solv = Solver_Herm(-10,10,0.005,20,V,T_rel)
solv.compute_all()

plt.figure()
plt.grid(True)
plt.plot(solv.x,solv.vectors_x[0]**2)
plt.plot(solv.x,solv.get_rho(32))
plt.plot(solv.x,theor_Psi2(alpha,solv.x))
plt.legend([r"$|\psi(x)|^2$",r"$\rho(x,x) \quad \beta=32$",r"$|\psi|^2_{nonrel}$"])
plt.show()

print("<x^2>=",solv.mean_x(x2))
print("<T>=",solv.mean_p(T_rel))
print("<V>=",solv.mean_x(V))
# Out:
# <x^2>= 1.9656208284748702
# <T>= 1.0967155786608782
# <V>= -0.3898608526710903

# %%
alpha=1
V = get_V_morse(alpha)
solv = Solver_Herm(-10,30,0.005,30,V,T_rel)
solv.compute_all()

plt.figure()
plt.grid(True)
plt.plot(solv.x,solv.vectors_x[0]**2)
plt.plot(solv.x,solv.get_rho(32))
plt.plot(solv.x,theor_Psi2(alpha,solv.x))
plt.legend([r"$|\psi(x)|^2$",r"$\rho(x,x) \quad \beta=32$",r"$|\psi|^2_{nonrel}$"])
plt.show()


print("<x^2>=",solv.mean_x(x2))
print("<T>=",solv.mean_p(T_rel))
print("<V>=",solv.mean_x(V))
# Out:
# <x^2>= 2.203896474993639
# <T>= 1.13747895708808
# <V>= -0.28833639921757104

# %%
def V_tw(x):
    x0=1.41
    return (x**2-x0**2)**2

# %%
solv = Solver_Herm(-10,10,0.01,20,V_tw,T_rel)
solv.compute_all()

plt.figure()
plt.grid(True)
plt.plot(solv.x,solv.vectors_x[0]**2)
plt.plot(solv.x,solv.get_rho(64))
plt.plot(solv.x,solv.get_rho(1/64))
plt.legend([r"$|\psi(x)|^2$",r"$\rho(x,x) \quad \beta=64$",r"$\rho(x,x) \quad \beta=1/64$"])
plt.show()

print("<x^2>=",solv.mean_x(x2))
print("<T>=",solv.mean_p(T_rel))
print("<V>=",solv.mean_x(V_tw))
# Out:
# <x^2>= 1.7446455506723748
# <T>= 1.673877811133276
# <V>= 0.717816585542983

# %%
y=np.zeros((3,solv.N))
y[0]=solv.vectors_x[0]**2
y[1]=solv.x
y[2]=solv.get_rho(1/64)
np.savetxt("reltwpsi2.txt",y)

# %%
def V_col(x):
    return -(x**2+1) ** (-0.5)

# %%
solv = Solver_Herm(-10,10,0.005,30,V_col,T)
solv.compute_all()

plt.figure()
plt.grid(True)
plt.plot(solv.x,solv.vectors_x[0]**2)
plt.plot(solv.x,solv.get_rho(16))
plt.legend([r"$|\psi(x)|^2$",r"$\rho(x,x) \quad \beta=4$"])
plt.show()

print("<x^2>=",solv.mean_x(x2))
print("<T>=",solv.mean_p(T_rel))
print("<V>=",solv.mean_x(V_col))
print(-solv.log_Z(16))
# Out:
# C:\Users\SEVA1\AppData\Local\Temp\ipykernel_9576\4053247200.py:5: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   Norm = 2**(-0.5 * n) * np.pi**-0.25 * (np.math.factorial(n))**-0.5
# <x^2>= 1.1911161035835696
# <T>= 0.09655015606009723
# <V>= -0.7812018299761678
# -10.7183715972235

# %%
y=np.zeros((2,solv.N))
y[0]=solv.vectors_x[0]**2
y[1]=solv.x
np.savetxt("relcolpsi2.txt",y)
