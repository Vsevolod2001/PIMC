# %%
import matplotlib.pyplot as plt

omega = 1
m = 100
N = 100
beta = 10
tau = beta / N
corr = [0.0049279, 0.00445719, 0.0040318, 0.00364688, 0.00329375, 0.00297512, 0.00268571, 0.00242197, 0.00217813, 0.00195686, 0.00176504, 0.001597, 0.0014406, 0.00130362, 0.00117932, 0.00107197, 0.000971531, 0.000873839, 0.000783014, 0.000698531, 0.000622945, 0.000554938, 0.000497423, 0.000446639, 0.000400234, 0.000360026, 0.000325092, 0.00028936, 0.000252744, 0.000222755, 0.00019756, 0.000178826, 0.000169581, 0.000165766, 0.000161208, 0.000158499, 0.000157808, 0.000156267, 0.000155463, 0.000151827, 0.000137475, 0.000124214, 0.000113485, 0.000104859, 9.63436e-05, 8.8317e-05, 8.17296e-05, 7.9884e-05, 7.83747e-05, 8.01024e-05, 8.44507e-05, 8.01024e-05, 7.83747e-05, 7.9884e-05, 8.17296e-05, 8.8317e-05, 9.63436e-05, 0.000104859, 0.000113485, 0.000124214, 0.000137475, 0.000151827, 0.000155463, 0.000156267, 0.000157808, 0.000158499, 0.000161208, 0.000165766, 0.000169581, 0.000178826, 0.00019756, 0.000222755, 0.000252744, 0.00028936, 0.000325092, 0.000360026, 0.000400234, 0.000446639, 0.000497423, 0.000554938, 0.000622945, 0.000698531, 0.000783014, 0.000873839, 0.000971531, 0.00107197, 0.00117932, 0.00130362, 0.0014406, 0.001597, 0.00176504, 0.00195686, 0.00217813, 0.00242197, 0.00268571, 0.00297512, 0.00329375, 0.00364688, 0.0040318, 0.00445719, 0.0049279]
x = [i * beta / N for i in range(N + 1)]

plt.plot(x, corr)
plt.show()

# %%
import matplotlib.pyplot as plt

omega = 1
m = 10
N = 100
beta = 10
tau = beta / N
corr = [0.0482165, 0.0437875, 0.0397512, 0.0361339, 0.0328051, 0.0297607, 0.0270138, 0.0244825, 0.0222039, 0.0201489, 0.0183026, 0.0166458, 0.0151002, 0.0137192, 0.012421, 0.0112716, 0.0102497, 0.00931179, 0.0084281, 0.00763501, 0.00697282, 0.00637519, 0.00579578, 0.00524782, 0.00469027, 0.00419239, 0.00376016, 0.00335117, 0.00299975, 0.00265075, 0.00236496, 0.00215769, 0.00196452, 0.00178665, 0.00162977, 0.00148276, 0.00135563, 0.00127519, 0.00120796, 0.00115448, 0.0011155, 0.00109623, 0.00112555, 0.00113097, 0.00108849, 0.00108302, 0.00112726, 0.00115736, 0.00118966, 0.00124266, 0.00121678, 0.00124266, 0.00118966, 0.00115736, 0.00112726, 0.00108302, 0.00108849, 0.00113097, 0.00112555, 0.00109623, 0.0011155, 0.00115448, 0.00120796, 0.00127519, 0.00135563, 0.00148276, 0.00162977, 0.00178665, 0.00196452, 0.00215769, 0.00236496, 0.00265075, 0.00299975, 0.00335117, 0.00376016, 0.00419239, 0.00469027, 0.00524782, 0.00579578, 0.00637519, 0.00697282, 0.00763501, 0.0084281, 0.00931179, 0.0102497, 0.0112716, 0.012421, 0.0137192, 0.0151002, 0.0166458, 0.0183026, 0.0201489, 0.0222039, 0.0244825, 0.0270138, 0.0297607, 0.0328051, 0.0361339, 0.0397512, 0.0437875, 0.0482165]
x = [i * beta / N for i in range(N + 1)]

plt.plot(x, corr)
plt.show()

# %%
import matplotlib.pyplot as plt

omega = 1
m = 1
N = 100
beta = 10
tau = beta / N
corr = [0.392501, 0.361773, 0.333519, 0.307446, 0.283335, 0.261201, 0.240658, 0.221871, 0.204776, 0.188963, 0.174495, 0.161116, 0.148541, 0.136946, 0.126175, 0.116168, 0.106934, 0.0985733, 0.090693, 0.0836987, 0.0773237, 0.0713712, 0.0662134, 0.0611666, 0.0567049, 0.0525145, 0.0489322, 0.045775, 0.043085, 0.0407685, 0.0383386, 0.0365845, 0.0353032, 0.0339074, 0.0324167, 0.0308972, 0.0295226, 0.0285374, 0.0276133, 0.026899, 0.0265193, 0.0267518, 0.027023, 0.0272673, 0.0275789, 0.0277296, 0.0281657, 0.0286108, 0.0289897, 0.0292072, 0.0292838, 0.0292072, 0.0289897, 0.0286108, 0.0281657, 0.0277296, 0.0275789, 0.0272673, 0.027023, 0.0267518, 0.0265193, 0.026899, 0.0276133, 0.0285374, 0.0295226, 0.0308972, 0.0324167, 0.0339074, 0.0353032, 0.0365845, 0.0383386, 0.0407685, 0.043085, 0.045775, 0.0489322, 0.0525145, 0.0567049, 0.0611666, 0.0662134, 0.0713712, 0.0773237, 0.0836987, 0.090693, 0.0985733, 0.106934, 0.116168, 0.126175, 0.136946, 0.148541, 0.161116, 0.174495, 0.188963, 0.204776, 0.221871, 0.240658, 0.261201, 0.283335, 0.307446, 0.333519, 0.361773, 0.392501]
x = [i * beta / N for i in range(N + 1)]

plt.plot(x, corr)
plt.show()

# %%
import matplotlib.pyplot as plt

omega = 10
m = 1
N = 100
beta = 10
tau = beta / N
corr = [0.0230994, 0.0142058, 0.0088298, 0.00556174, 0.00350266, 0.00216692, 0.00133431, 0.00077005, 0.000371054, 0.000196478, 8.0835e-05, 2.88485e-05, 7.83693e-05, 0.000101994, 0.000190006, 0.000174721, 0.000145941, 9.86423e-05, 4.05725e-05, 8.06395e-05, 0.000111084, 0.000165976, 0.000228239, 0.000262868, 0.000212187, 0.000170873, 1.17631e-06, -6.88671e-05, -0.000105718, -0.000119975, -0.00011351, -0.000106385, -0.00010985, -0.000143841, -0.000115869, -9.73559e-05, -0.00012506, -0.000210497, -0.000194067, -0.000100932, -0.000128767, -9.20988e-05, -5.68004e-05, -5.29324e-05, -3.39788e-05, -1.05529e-05, -4.26836e-06, -4.36846e-06, -2.93449e-05, -6.38116e-05, -7.66366e-05, -6.38116e-05, -2.93449e-05, -4.36846e-06, -4.26836e-06, -1.05529e-05, -3.39788e-05, -5.29324e-05, -5.68004e-05, -9.20988e-05, -0.000128767, -0.000100932, -0.000194067, -0.000210497, -0.00012506, -9.73559e-05, -0.000115869, -0.000143841, -0.00010985, -0.000106385, -0.00011351, -0.000119975, -0.000105718, -6.88671e-05, 1.17631e-06, 0.000170873, 0.000212187, 0.000262868, 0.000228239, 0.000165976, 0.000111084, 8.06395e-05, 4.05725e-05, 9.86423e-05, 0.000145941, 0.000174721, 0.000190006, 0.000101994, 7.83693e-05, 2.88485e-05, 8.0835e-05, 0.000196478, 0.000371054, 0.00077005, 0.00133431, 0.00216692, 0.00350266, 0.00556174, 0.0088298, 0.0142058, 0.0230994]
x = [i * beta / N for i in range(N + 1)]

plt.plot(x, corr)
plt.show()

# %%
import matplotlib.pyplot as plt

omega = 100
m = 1
N = 100
beta = 10
tau = beta / N
corr = [0.000797659, 9.44046e-05, 9.8738e-06, 2.25811e-06, -1.23493e-06, 1.11853e-07, 2.73756e-06, 1.01403e-06, 4.69231e-06, 3.26896e-06, 2.62945e-06, 5.88354e-07, -2.70322e-06, -1.63419e-06, 3.86424e-06, -9.07432e-07, 1.52024e-06, -5.1901e-06, 3.02626e-06, 4.3334e-06, 7.81114e-07, -1.81484e-06, 1.53492e-06, 1.35401e-07, -1.83005e-06, 2.35538e-06, -5.10841e-07, -2.40709e-06, -7.09735e-07, -3.65308e-06, 1.80273e-06, -4.27139e-06, -6.37416e-06, -2.12458e-06, 8.46026e-07, -3.90361e-07, -3.66259e-06, -5.41552e-07, 2.47145e-06, 3.82306e-06, 9.40157e-07, -2.86699e-06, -1.46532e-06, -1.5176e-06, -1.60226e-06, -2.64374e-06, -2.91166e-06, 3.45334e-06, -7.16998e-08, -2.32073e-06, 3.66705e-09, -2.32073e-06, -7.16998e-08, 3.45334e-06, -2.91166e-06, -2.64374e-06, -1.60226e-06, -1.5176e-06, -1.46532e-06, -2.86699e-06, 9.40157e-07, 3.82306e-06, 2.47145e-06, -5.41552e-07, -3.66259e-06, -3.90361e-07, 8.46026e-07, -2.12458e-06, -6.37416e-06, -4.27139e-06, 1.80273e-06, -3.65308e-06, -7.09735e-07, -2.40709e-06, -5.10841e-07, 2.35538e-06, -1.83005e-06, 1.35401e-07, 1.53492e-06, -1.81484e-06, 7.81114e-07, 4.3334e-06, 3.02626e-06, -5.1901e-06, 1.52024e-06, -9.07432e-07, 3.86424e-06, -1.63419e-06, -2.70322e-06, 5.88354e-07, 2.62945e-06, 3.26896e-06, 4.69231e-06, 1.01403e-06, 2.73756e-06, 1.11853e-07, -1.23493e-06, 2.25811e-06, 9.8738e-06, 9.44046e-05, 0.000797659]
x = [i * beta / N for i in range(N + 1)]

plt.plot(x, corr)
plt.show()

# %%
import matplotlib.pyplot as plt

omega = 1000
m = 1
N = 100
beta = 10
tau = beta / N
corr = [1.00006e-05, -1.44961e-08, 1.6751e-08, 4.87217e-09, 2.35117e-08, 1.10747e-08, -7.07642e-08, 2.22292e-08, 2.9693e-09, 2.37789e-08, 3.96122e-08, -2.41204e-08, -3.00339e-08, -4.91033e-08, 3.1009e-09, -1.24818e-08, -4.92851e-08, -3.58822e-10, -1.67268e-08, -1.88623e-08, -6.67327e-08, -7.16726e-09, 9.71012e-10, -4.67329e-08, 3.74805e-08, -1.91624e-08, 1.14943e-08, -4.54076e-08, 2.25589e-08, -4.30861e-10, -4.6896e-08, 2.54412e-09, -4.33746e-08, -5.15704e-08, 6.79941e-08, 8.71579e-09, -5.14544e-08, -2.33312e-08, 3.33461e-08, 4.92303e-08, 3.00203e-08, 6.68023e-08, -5.48074e-08, -2.74229e-08, 1.09793e-08, 1.20051e-08, 4.77913e-09, -4.86097e-08, 2.16706e-08, -9.48621e-09, -9.16127e-08, -9.48621e-09, 2.16706e-08, -4.86097e-08, 4.77913e-09, 1.20051e-08, 1.09793e-08, -2.74229e-08, -5.48074e-08, 6.68023e-08, 3.00203e-08, 4.92303e-08, 3.33461e-08, -2.33312e-08, -5.14544e-08, 8.71579e-09, 6.79941e-08, -5.15704e-08, -4.33746e-08, 2.54412e-09, -4.6896e-08, -4.30861e-10, 2.25589e-08, -4.54076e-08, 1.14943e-08, -1.91624e-08, 3.74805e-08, -4.67329e-08, 9.71012e-10, -7.16726e-09, -6.67327e-08, -1.88623e-08, -1.67268e-08, -3.58822e-10, -4.92851e-08, -1.24818e-08, 3.1009e-09, -4.91033e-08, -3.00339e-08, -2.41204e-08, 3.96122e-08, 2.37789e-08, 2.9693e-09, 2.22292e-08, -7.07642e-08, 1.10747e-08, 2.35117e-08, 4.87217e-09, 1.6751e-08, -1.44961e-08, 1.00006e-05]
x = [i * beta / N for i in range(N + 1)]

plt.plot(x, corr)
plt.show()

# %%
import matplotlib.pyplot as plt

omega = 10
m = 0.1
N = 100
beta = 10
tau = beta / N
corr = [0.00480947, 0.00166766, 0.000568823, 0.000197199, 6.86979e-05, -3.65171e-06, -2.3111e-05, -3.88891e-06, -1.74868e-05, -2.52384e-05, -1.17755e-05, 1.75299e-06, -1.33993e-05, -4.93832e-06, 7.70269e-06, -8.93705e-06, -1.29726e-05, -1.04149e-05, -4.42292e-06, 6.30222e-06, 1.93983e-05, 3.2357e-05, -7.27987e-06, -4.3175e-06, 7.45157e-06, 7.34914e-06, 6.46274e-06, 2.02875e-06, 2.44242e-05, 7.22231e-06, 2.4546e-05, 1.25899e-05, 1.13531e-05, -1.11371e-06, 1.25727e-06, 2.35944e-05, 5.19307e-06, -1.06922e-05, 6.39409e-06, 1.67048e-05, -1.43741e-05, -1.55211e-05, -9.08069e-06, -1.74636e-05, 1.5252e-05, 2.2031e-05, -2.28631e-06, 2.32198e-06, -5.98127e-06, 8.39124e-06, -4.73771e-06, 8.39124e-06, -5.98127e-06, 2.32198e-06, -2.28631e-06, 2.2031e-05, 1.5252e-05, -1.74636e-05, -9.08069e-06, -1.55211e-05, -1.43741e-05, 1.67048e-05, 6.39409e-06, -1.06922e-05, 5.19307e-06, 2.35944e-05, 1.25727e-06, -1.11371e-06, 1.13531e-05, 1.25899e-05, 2.4546e-05, 7.22231e-06, 2.44242e-05, 2.02875e-06, 6.46274e-06, 7.34914e-06, 7.45157e-06, -4.3175e-06, -7.27987e-06, 3.2357e-05, 1.93983e-05, 6.30222e-06, -4.42292e-06, -1.04149e-05, -1.29726e-05, -8.93705e-06, 7.70269e-06, -4.93832e-06, -1.33993e-05, 1.75299e-06, -1.17755e-05, -2.52384e-05, -1.74868e-05, -3.88891e-06, -2.3111e-05, -3.65171e-06, 6.86979e-05, 0.000197199, 0.000568823, 0.00166766, 0.00480947]
x = [i * beta / N for i in range(N + 1)]

plt.plot(x, corr)
plt.show()
