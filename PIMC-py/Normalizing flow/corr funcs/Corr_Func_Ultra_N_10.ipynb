# %%
import matplotlib.pyplot as plt

omega = 10000
m = 1
N = 10
beta = 10
tau = beta / N
corr = [9.90906e-09, 3.28199e-10, 6.67025e-11, 1.40456e-11, -2.08743e-10, -3.11262e-10, -2.08743e-10, 1.40456e-11, 6.67025e-11, 3.28199e-10, 9.90906e-09]
x = [i * beta / N for i in range(N + 1)]

plt.plot(x, corr)
plt.show()

# %%
import matplotlib.pyplot as plt

omega = 1000
m = 1
N = 10
beta = 10
tau = beta / N
corr = [9.6574e-07, 4.50555e-08, 5.76671e-08, 8.70278e-08, 5.45357e-09, 1.68998e-08, 5.45357e-09, 8.70278e-08, 5.76671e-08, 4.50555e-08, 9.6574e-07]
x = [i * beta / N for i in range(N + 1)]

plt.plot(x, corr)
plt.show()

# %%
import matplotlib.pyplot as plt

omega = 100
m = 1
N = 10
beta = 10
tau = beta / N
corr = [9.80907e-05, -2.46557e-06, -3.03401e-06, 6.69381e-07, -1.88334e-06, 6.29651e-06, -1.88334e-06, 6.69381e-07, -3.03401e-06, -2.46557e-06, 9.80907e-05]
x = [i * beta / N for i in range(N + 1)]

plt.plot(x, corr)
plt.show()

# %%
import matplotlib.pyplot as plt

omega = 10
m = 1
N = 10
beta = 10
tau = beta / N
corr = [0.00927846, 0.000183929, -0.0001821, 0.000237403, -0.000296802, 0.000606529, -0.000296802, 0.000237403, -0.0001821, 0.000183929, 0.00927846]
x = [i * beta / N for i in range(N + 1)]

plt.plot(x, corr)
plt.show()

# %%
import matplotlib.pyplot as plt

omega = 1
m = 1
N = 10
beta = 10
tau = beta / N
corr = [0.476546, 0.148654, 0.060357, 0.0232596, -0.00447499, -0.00224423, -0.00447499, 0.0232596, 0.060357, 0.148654, 0.476546]
x = [i * beta / N for i in range(N + 1)]

plt.plot(x, corr)
plt.show()
