# %%
import matplotlib.pyplot as plt

omega = 100
m = 1
N = 100
beta = 10
tau = beta / N
corr = [0.000790531, 8.69011e-05, 1.35541e-05, 5.948e-06, 9.04169e-07, 6.44759e-07, 2.52303e-06, -1.25464e-06, 3.70089e-06, -1.58055e-06, 4.28998e-06, 5.61801e-06, -1.71701e-06, -4.54831e-06, 3.25238e-06, -1.61395e-06, -2.71149e-06, -9.40202e-07, 4.66059e-06, 3.68093e-06, 7.68558e-07, -1.37575e-06, 4.89402e-06, 3.61987e-06, 6.6761e-06, 7.07827e-06, 4.79798e-06, -1.27223e-07, -6.72496e-06, -3.06421e-06, -3.6263e-06, -1.41079e-06, -3.75566e-06, 5.98883e-06, 4.19798e-06, 2.66611e-08, 2.49713e-06, -3.61384e-06, 2.81486e-07, -3.45525e-06, -6.11604e-06, -1.9974e-07, -2.9351e-06, -4.38914e-07, 1.66251e-06, 5.5297e-06, -2.79611e-07, 6.23687e-06, 7.16654e-06, -6.88472e-07, 4.41707e-06, -6.88472e-07, 7.16654e-06, 6.23687e-06, -2.79611e-07, 5.5297e-06, 1.66251e-06, -4.38914e-07, -2.9351e-06, -1.9974e-07, -6.11604e-06, -3.45525e-06, 2.81486e-07, -3.61384e-06, 2.49713e-06, 2.66611e-08, 4.19798e-06, 5.98883e-06, -3.75566e-06, -1.41079e-06, -3.6263e-06, -3.06421e-06, -6.72496e-06, -1.27223e-07, 4.79798e-06, 7.07827e-06, 6.6761e-06, 3.61987e-06, 4.89402e-06, -1.37575e-06, 7.68558e-07, 3.68093e-06, 4.66059e-06, -9.40202e-07, -2.71149e-06, -1.61395e-06, 3.25238e-06, -4.54831e-06, -1.71701e-06, 5.61801e-06, 4.28998e-06, -1.58055e-06, 3.70089e-06, -1.25464e-06, 2.52303e-06, 6.44759e-07, 9.04169e-07, 5.948e-06, 1.35541e-05, 8.69011e-05, 0.000790531]
x = [i * beta / N for i in range(N + 1)]

plt.plot(x, corr)
plt.show()

# %%
import matplotlib.pyplot as plt

omega = 10
m = 1
N = 100
beta = 10
tau = beta / N
corr = [0.0245524, 0.0147464, 0.00905302, 0.00570503, 0.00361604, 0.00227153, 0.00146513, 0.000839935, 0.000505578, 0.000336522, 0.000107796, 1.15905e-05, -2.97293e-05, -8.97133e-05, -0.000170159, -5.8333e-05, -3.95097e-05, -5.64506e-05, -3.11941e-05, 2.4483e-05, 9.11918e-05, 0.000147573, 0.000117109, 4.19669e-05, -5.84263e-05, -4.88067e-05, -0.000106689, -9.73539e-05, -4.46637e-05, -5.28034e-05, -2.59136e-05, 4.56207e-05, 8.95009e-06, -1.66664e-05, -0.000107787, -0.00019323, -0.000159426, -0.00013404, -0.000184585, -7.77144e-05, -5.99262e-05, -3.45705e-05, -5.79418e-05, -8.54365e-05, -0.000131341, -7.75526e-05, 7.72963e-05, 6.84416e-05, 0.000129366, 0.000154139, 0.000167456, 0.000154139, 0.000129366, 6.84416e-05, 7.72963e-05, -7.75526e-05, -0.000131341, -8.54365e-05, -5.79418e-05, -3.45705e-05, -5.99262e-05, -7.77144e-05, -0.000184585, -0.00013404, -0.000159426, -0.00019323, -0.000107787, -1.66664e-05, 8.95009e-06, 4.56207e-05, -2.59136e-05, -5.28034e-05, -4.46637e-05, -9.73539e-05, -0.000106689, -4.88067e-05, -5.84263e-05, 4.19669e-05, 0.000117109, 0.000147573, 9.11918e-05, 2.4483e-05, -3.11941e-05, -5.64506e-05, -3.95097e-05, -5.8333e-05, -0.000170159, -8.97133e-05, -2.97293e-05, 1.15905e-05, 0.000107796, 0.000336522, 0.000505578, 0.000839935, 0.00146513, 0.00227153, 0.00361604, 0.00570503, 0.00905302, 0.0147464, 0.0245524]
x = [i * beta / N for i in range(N + 1)]

plt.plot(x, corr)
plt.show()

# %%
import matplotlib.pyplot as plt

omega = 1
m = 1
N = 100
beta = 10
tau = beta / N
corr = [0.555858, 0.497988, 0.446597, 0.401115, 0.360415, 0.324316, 0.29138, 0.261791, 0.235658, 0.211969, 0.190536, 0.171994, 0.155133, 0.140335, 0.126598, 0.114471, 0.103514, 0.0941716, 0.0852865, 0.0767528, 0.0691313, 0.0619047, 0.0550745, 0.0490998, 0.0443236, 0.0396256, 0.0358628, 0.0324961, 0.0302019, 0.0276177, 0.0251373, 0.0226234, 0.0203086, 0.0179717, 0.0164385, 0.0152739, 0.0143051, 0.0136778, 0.0127566, 0.0118486, 0.0111658, 0.0111462, 0.011026, 0.0110081, 0.0109681, 0.0106729, 0.0101027, 0.010377, 0.010866, 0.0114044, 0.0119873, 0.0114044, 0.010866, 0.010377, 0.0101027, 0.0106729, 0.0109681, 0.0110081, 0.011026, 0.0111462, 0.0111658, 0.0118486, 0.0127566, 0.0136778, 0.0143051, 0.0152739, 0.0164385, 0.0179717, 0.0203086, 0.0226234, 0.0251373, 0.0276177, 0.0302019, 0.0324961, 0.0358628, 0.0396256, 0.0443236, 0.0490998, 0.0550745, 0.0619047, 0.0691313, 0.0767528, 0.0852865, 0.0941716, 0.103514, 0.114471, 0.126598, 0.140335, 0.155133, 0.171994, 0.190536, 0.211969, 0.235658, 0.261791, 0.29138, 0.324316, 0.360415, 0.401115, 0.446597, 0.497988, 0.555858]
x = [i * beta / N for i in range(N + 1)]

plt.plot(x, corr)
plt.show()
