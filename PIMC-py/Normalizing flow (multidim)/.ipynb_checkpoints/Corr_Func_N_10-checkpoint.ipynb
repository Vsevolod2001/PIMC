# %%
import matplotlib.pyplot as plt

omega = 10
m = 0.1
N = 10
beta = 10
tau = beta / N
corr = [0.0774669, 0.00808093, 7.02603e-05, 0.000655958, 0.000308913, 0.00129103, 0.000308913, 0.000655958, 7.02603e-05, 0.00808093, 0.0774669]
x = [i * beta / N for i in range(N + 1)]

plt.plot(x, corr)
plt.show()

# %%
import matplotlib.pyplot as plt

omega = 10
m = 1
N = 10
beta = 10
tau = beta / N
corr = [0.00955263, 0.000227443, -0.000211174, -5.79625e-05, 8.54077e-05, 2.42329e-05, 8.54077e-05, -5.79625e-05, -0.000211174, 0.000227443, 0.00955263]
x = [i * beta / N for i in range(N + 1)]

plt.plot(x, corr)
plt.show()

# %%
import matplotlib.pyplot as plt

omega = 1
m = 1
N = 10
beta = 10
tau = beta / N
corr = [0.389004, 0.174591, 0.0750764, 0.0320855, 0.0235634, 0.0204869, 0.0235634, 0.0320855, 0.0750764, 0.174591, 0.389004]
x = [i * beta / N for i in range(N + 1)]

plt.plot(x, corr)
plt.show()

# %%
import matplotlib.pyplot as plt

omega = 1
m = 10
N = 10
beta = 10
tau = beta / N
corr = [0.0433519, 0.0165621, 0.00659864, 0.00226515, 0.00113901, 0.000572457, 0.00113901, 0.00226515, 0.00659864, 0.0165621, 0.0433519]
x = [i * beta / N for i in range(N + 1)]

plt.plot(x, corr)
plt.show()

# %%
import matplotlib.pyplot as plt

omega = 0.1
m = 10
N = 10
beta = 10
tau = beta / N
corr = [1.07426, 1.03137, 0.999426, 0.975832, 0.962358, 0.958507, 0.962358, 0.975832, 0.999426, 1.03137, 1.07426]
x = [i * beta / N for i in range(N + 1)]

plt.plot(x, corr)
plt.show()
