# %% [markdown]
# # Model
#
# $H = \frac{p ^ 2}{2 m} + \frac{1}{2} ((e ^ {-\alpha x} - 1) ^ 2 - 1)$
#
# ## Fit dependence with
#
# $\langle q^2 \rangle = A e ^ {-B N _ s ^ C} + D$
#
# $\langle V(q) \rangle = A e ^ {-B N _ s ^ C} + D$
#
# $\langle K(p) \rangle = A e ^ {-B N _ s ^ C} + D$
#
# ## Lattice size
#
# N = 256

# %% [markdown]
# ## General parameters and functions

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.special import kv

d = 1
N = 256
m = 1.000000
alpha = 0.125
beta = 32
Np = 256
Na = 8
tau = beta / N

def f(x, a, b, c, d):
    return a * np.exp(-b * x ** c) + d

def GetStr(number):
    number = 1.0 * number
    return str(number).split('.')[0] + '.' + str(number).split('.')[1] + '0' * (6 - len(str(number).split('.')[1]))

def GetX2(path : list) -> float:
    mean = 0
    for point in path:
        for dimension in range(d):
            mean += point[dimension] ** 2 / N
    return mean

def GetV(path : list) -> float:
    mean = 0
    for point in path:
        Q = 0
        for dimension in range(d):
            Q += point[dimension]
        mean += 0.5 * ((np.exp(-alpha * Q) - 1) ** 2 - 1) / N
    return mean

def GetK(path : list) -> float:
    mean = 0
    for index in range(len(path)):
        prev = len(path) - 1 if index == 0 else index - 1
        Q = 0
        for dimension in range(d):
            Q += (path[index][dimension] - path[prev][dimension]) ** 2
        mean += (1 / (2 * tau) - m * Q / (2 * tau ** 2)) / N
    return mean

x2_a = []
v_a = []
k_a = []

# %% [markdown]
# ## $a = 0.125$

# %%
Number_of_cores = 64
Ns_max = 1048576

mask = "_Cold_m=" + GetStr(m) + "_alpha=" + GetStr(alpha) + "_N=" + str(N) + "_Ns="
Ns_set = [2 ** i for i in range(int(np.log2(Ns_max)) + 1)]

x2_Ns = []
v_Ns = []
k_Ns = []
    
for Ns in Ns_set:
    paths = []
    x2 = []
    v = []
    k = []
    for rank in range(Number_of_cores):
        file = open("Data/" + str(rank) + mask + str(Ns) + ".dat", "r")
        data = file.readlines()
        for line in data:
            path = np.array(list(map(float, line.split()))).reshape(N, d)
            paths.append(path)
        file.close()
    for path in paths:
        x2.append(GetX2(path))
        v.append(GetV(path))
        k.append(GetK(path))
    x2_Ns.append([Ns, np.mean(x2), np.std(x2) / ((N - 1) ** 0.5)])
    v_Ns.append([Ns, np.mean(v), np.std(v) / ((N - 1) ** 0.5)])
    k_Ns.append([Ns, np.mean(k), np.std(k) / ((N - 1) ** 0.5)])

x2_Ns = np.array(x2_Ns)
v_Ns = np.array(v_Ns)
k_Ns = np.array(k_Ns)

popt_x2, pcov_x2 = curve_fit(f, np.log2(x2_Ns[:, 0]), x2_Ns[:, 1], maxfev=10000, p0 = [-6, 0, 5, 7])
popt_v, pcov_v = curve_fit(f, np.log2(v_Ns[:, 0]), v_Ns[:, 1])
popt_k, pcov_k = curve_fit(f, np.log2(k_Ns[:, 0]), k_Ns[:, 1])

x2_Ns_Warm = []
v_Ns_Warm = []
k_Ns_Warm = []

mask_warm = "_Warm_m=" + GetStr(m) + "_alpha=" + GetStr(alpha) + "_N=" + str(N) + "_Ns="
Ns_set = [2 ** i for i in range(int(np.log2(Ns_max)) + 1)]

for Ns in Ns_set:
    paths = []
    x2 = []
    v = []
    k = []
    for rank in range(Number_of_cores):
        file = open("Data/" + str(rank) + mask_warm + str(Ns) + ".dat", "r")
        data = file.readlines()
        for line in data:
            path = np.array(list(map(float, line.split()))).reshape(N, d)
            paths.append(path)
        file.close()
    for path in paths:
        x2.append(GetX2(path))
        v.append(GetV(path))
        k.append(GetK(path))
    x2_Ns_Warm.append([Ns, np.mean(x2), np.std(x2) / ((N - 1) ** 0.5)])
    v_Ns_Warm.append([Ns, np.mean(v), np.std(v) / ((N - 1) ** 0.5)])
    k_Ns_Warm.append([Ns, np.mean(k), np.std(k) / ((N - 1) ** 0.5)]) 

x2_Ns_Warm = np.array(x2_Ns_Warm)
v_Ns_Warm = np.array(v_Ns_Warm)
k_Ns_Warm = np.array(k_Ns_Warm)

print("\nx2\n")
print(x2_Ns.tolist())
print("\nFit parameters\n")
print(popt_x2.tolist())
print("\nFit covariance\n")
print(np.diag(pcov_x2).tolist())
plt.errorbar(x = np.log2(x2_Ns[:, 0]), y = x2_Ns[:, 1], yerr = x2_Ns[:, 2], fmt = "bo", label = r"Thermalization of $\langle q^2 \rangle$")
plt.plot(np.log2(x2_Ns[:, 0]), f(np.log2(x2_Ns[:, 0]), *popt_x2), 'k--',
         label=r'Fit: A=%5.3f, B=%5.6f, C=%5.3f, D=%5.3f' % tuple(popt_x2))
plt.errorbar(x = np.log2(x2_Ns_Warm[:, 0]), y = x2_Ns_Warm[:, 1], yerr = x2_Ns_Warm[:, 2], fmt = "ro", label = r"Warm thermalization of $\langle q^2 \rangle$")
plt.title(r"m = " + str(m) + r", $\alpha = $" + str(alpha) + r", $N = $" + str(N) + r", $\beta = $" + str(beta))
plt.xlabel(r"$log_2 N_s$")
plt.ylabel(r"$\langle x^2 \rangle$")
plt.legend()
plt.show()

print("\nV\n")
print(v_Ns.tolist())
print("\nFit parameters\n")
print(popt_v.tolist())
print("\nFit covariance\n")
print(np.diag(pcov_v).tolist())
plt.errorbar(x = np.log2(v_Ns[:, 0]), y = v_Ns[:, 1], yerr = v_Ns[:, 2], fmt = "bo", label = "Холодный старт")
#plt.plot(np.log2(v_Ns[:, 0]), f(np.log2(v_Ns[:, 0]), *popt_v), 'k--',
#         label=r'Fit: A=%5.3f, B=%5.6f, C=%5.3f, D=%5.3f' % tuple(popt_v))
plt.errorbar(x = np.log2(v_Ns_Warm[:, 0]), y = v_Ns_Warm[:, 1], yerr = v_Ns_Warm[:, 2], fmt = "ro", label = "Старт с данных нейросети")
plt.hlines(-0.469, 0, 18, color = "green", label = "Непрерывный предел")
plt.title(r"$\alpha = $" + str(alpha) + r", $N = $" + str(N) + r", $\beta = $" + str(beta))
plt.xlabel(r"$log_2 N_s$")
plt.ylabel(r"$\langle V(x) \rangle$")
plt.legend()
plt.show()

print("\nK\n")
print(k_Ns.tolist())
print("\nFit parameters\n")
print(popt_k.tolist())
print("\nFit covariance\n")
print(np.diag(pcov_k).tolist())
plt.errorbar(x = np.log2(k_Ns[:, 0]), y = k_Ns[:, 1], yerr = k_Ns[:, 2], fmt = "bo", label = "Холодный старт")
#plt.plot(np.log2(k_Ns[:, 0]), f(np.log2(k_Ns[:, 0]), *popt_k), 'k--',
#         label=r'Fit: A=%5.3f, B=%5.6f, C=%5.3f, D=%5.3f' % tuple(popt_k))
plt.errorbar(x = np.log2(k_Ns_Warm[:, 0]), y = k_Ns_Warm[:, 1], yerr = k_Ns_Warm[:, 2], fmt = "ro", label = "Старт с данных нейросети")
plt.hlines(0.029, 0, 18, color = "green", label = "Непрерывный предел")
plt.title(r"$\alpha = $" + str(alpha) + r", $N = $" + str(N) + r", $\beta = $" + str(beta))
plt.xlabel(r"$log_2 N_s$")
plt.ylabel(r"$\langle K(p) \rangle$")
plt.legend()
plt.show()
# Out:
# /var/folders/sf/z2_k64nn16l9x71mf6mwhs6h0000gn/T/ipykernel_50887/1926970843.py:16: RuntimeWarning: divide by zero encountered in power
#   return a * np.exp(-b * x ** c) + d
# x2
#
# [[1.0, 0.04905127283715438, 0.0004283692593346655], [2.0, 0.08184297033310647, 0.0006428180845884485], [4.0, 0.12681595365948226, 0.001041348676644936], [8.0, 0.18908757671033455, 0.0018671914900793764], [16.0, 0.2718377409955123, 0.0030083288376463635], [32.0, 0.38508905286217215, 0.0050931998949723875], [64.0, 0.5410552504319196, 0.00850635849952891], [128.0, 0.7904834060805046, 0.014419673662023812], [256.0, 1.0705079774584723, 0.02342937127567322], [512.0, 1.5244036364592142, 0.03740561303096327], [1024.0, 2.0529162732776776, 0.062019112309839905], [2048.0, 2.599692538288127, 0.09381825340242024], [4096.0, 3.476769745145115, 0.14721066260247453], [8192.0, 3.8228573015877476, 0.1797461963295986], [16384.0, 4.67455573959612, 0.29414216255766074], [32768.0, 5.463564470078213, 0.38180790914956086], [65536.0, 4.885458697200482, 0.2983726078873817], [131072.0, 5.203979041203435, 0.3810140822849621], [262144.0, 5.7204267158410635, 0.4426759509527537], [524288.0, 6.10629977190652, 0.5067053869211272], [1048576.0, 5.906086744549817, 0.46923713598309397]]
#
# Fit parameters
#
# [-5.785417457643582, 0.00010390677439039791, 3.606886473201163, 5.91044711419992]
#
# Fit covariance
#
# [0.03858032117343636, 5.413394270946837e-09, 0.08371306319117913, 0.02441207148391753]
# V
#
# [[1.0, -0.49961609591264333, 3.372724969378294e-06], [2.0, -0.49935956084413924, 5.024099923397673e-06], [4.0, -0.4990051282186446, 8.264507908179403e-06], [8.0, -0.49851440366067984, 1.5057109886314844e-05], [16.0, -0.49786369597427277, 2.4042226155034466e-05], [32.0, -0.49696396573595963, 4.1772368151896066e-05], [64.0, -0.49571333267231005, 6.883611140222615e-05], [128.0, -0.4936973021328462, 0.00012142012020149496], [256.0, -0.4913694445283233, 0.00021020144857868307], [512.0, -0.4875151163281654, 0.0003559993579831165], [1024.0, -0.48350799974028946, 0.000541642048087495], [2048.0, -0.479536091117535, 0.0007877542270656995], [4096.0, -0.47349398308061913, 0.0010654548242543663], [8192.0, -0.4719530686808286, 0.0011935848918742198], [16384.0, -0.4688282162725933, 0.0014222808913419806], [32768.0, -0.4665213371387248, 0.0015446008446966088], [65536.0, -0.46899615986638193, 0.0014147017923627969], [131072.0, -0.4680398779172001, 0.0015595617522658472], [262144.0, -0.46582929702487236, 0.001765731141539763], [524288.0, -0.46460008828369237, 0.001771357986483582], [1048576.0, -0.4661039890389461, 0.0016752921038396167]]
#
# Fit parameters
#
# [-0.03269616734671039, 9.112599275417976e-05, 3.859477618544828, -0.4662484461388933]
#
# Fit covariance
#
# [4.4376214946933456e-07, 2.683779679979735e-09, 0.0570272602031676, 2.1254027743103333e-07]
# K
#
# [[1.0, 1.8359241462107239, 0.016278722084551667], [2.0, 1.1370306766398277, 0.017710781614154507], [4.0, 0.693498534675178, 0.0197017529565014], [8.0, 0.45673616591137617, 0.02085623874494713], [16.0, 0.32411851835538985, 0.0205349206127787], [32.0, 0.20665285951638518, 0.020860722036923754], [64.0, 0.15759531121973014, 0.021901640815346336], [128.0, 0.09270126980246277, 0.022930633021853438], [256.0, 0.09148223051341994, 0.021709746544964267], [512.0, 0.058552751098694074, 0.021392739594002282], [1024.0, 0.04323448566564053, 0.02179072957891639], [2048.0, 0.039523293541087336, 0.023231957023997364], [4096.0, 0.01027972735102484, 0.02171570005832978], [8192.0, 0.03050060830276683, 0.021550958836231097], [16384.0, -0.017317226360248815, 0.022836921375432067], [32768.0, 0.032426631711765797, 0.02116496806276386], [65536.0, 0.01961039857610734, 0.02186960504545389], [131072.0, 0.024642929610742378, 0.022092633002008786], [262144.0, 0.029415478783062058, 0.023060418066349297], [524288.0, 0.05708010294303513, 0.022147027235642165], [1048576.0, 0.02372947388231065, 0.02211716967965205]]
#
# Fit parameters
#
# [1.8158690392245744, 0.5022394207826815, 0.9398884130896111, 0.022341538503644603]
#
# Fit covariance
#
# [0.00035597584371130554, 0.00024029941900366122, 0.0006683434963510843, 3.4196348045880435e-05]

# %%
file = open("Data/" + str(63) + mask + str(Ns_max) + ".dat", "r")
data = file.readlines()
y = np.array(list(map(float, data[0].split()))).reshape(N, d)
x = []
for i in range(N):
    x.append(i * tau)
plt.plot(x, y, "ko")
plt.show()

# %%
from scipy.special import gamma
import numpy as np

xmax = 15
delta = 0.1
rho = [0 for i in range(2 * int(xmax / delta) + 1)]
rho_warm = [0 for i in range(2 * int(xmax / delta) + 1)]
x = [i * delta - xmax for i in range(len(rho))]
y = []

for point in x:
    y.append(
        2 ** (2 / alpha - 1) * (2 - alpha) / alpha ** (2 / alpha - 1) / gamma(2 / alpha) * np.exp(-2 / alpha * np.exp(-alpha * point) - (2 - alpha) * point)
    )

for core in range(Number_of_cores):
    file = open("Data/" + str(core) + mask + str(Ns_max) + ".dat", "r")
    data = file.readlines()
    for line in data:
        path = np.array(list(map(float, line.split()))).reshape(N, d)
        for point in path:
            index = int((xmax + point) / delta)
            rho[index] += 1 / (Number_of_cores * len(data) * len(path) * delta)

for core in range(Number_of_cores):
    file = open("Data/" + str(core) + mask_warm + str(Ns_max) + ".dat", "r")
    data = file.readlines()
    for line in data:
        path = np.array(list(map(float, line.split()))).reshape(N, d)
        for point in path:
            index = int((xmax + point) / delta)
            rho_warm[index] += 1 / (Number_of_cores * len(data) * len(path) * delta)
            
plt.plot(x, rho, "b.", label = "Холодный старт")
plt.plot(x, rho_warm, "r.", label = "Старт с данных нейросети")
plt.plot(x, y, "g-", label = "Теоретическое предсказание")
plt.title(r"$\alpha = $" + str(alpha) + r", $N = $" + str(N) + r", $\beta = $" + str(beta))
plt.xlabel(r"$x$")
plt.ylabel(r"$|\psi (x)|^2$")
plt.legend()
plt.show()

# %% [markdown]
# ## $a = 1$

# %%
alpha = 1

# %%
Number_of_cores = 64
Ns_max = 131072

mask = "_Cold_m=" + GetStr(m) + "_alpha=" + GetStr(alpha) + "_N=" + str(N) + "_Ns="
Ns_set = [2 ** i for i in range(int(np.log2(Ns_max)) + 1)]

x2_Ns = []
v_Ns = []
k_Ns = []
    
for Ns in Ns_set:
    paths = []
    x2 = []
    v = []
    k = []
    for rank in range(Number_of_cores):
        file = open("Data/" + str(rank) + mask + str(Ns) + ".dat", "r")
        data = file.readlines()
        for line in data:
            path = np.array(list(map(float, line.split()))).reshape(N, d)
            paths.append(path)
        file.close()
    for path in paths:
        x2.append(GetX2(path))
        v.append(GetV(path))
        k.append(GetK(path))
    x2_Ns.append([Ns, np.mean(x2), np.std(x2) / ((N - 1) ** 0.5)])
    v_Ns.append([Ns, np.mean(v), np.std(v) / ((N - 1) ** 0.5)])
    k_Ns.append([Ns, np.mean(k), np.std(k) / ((N - 1) ** 0.5)])

x2_Ns = np.array(x2_Ns)
v_Ns = np.array(v_Ns)
k_Ns = np.array(k_Ns)

popt_x2, pcov_x2 = curve_fit(f, np.log2(x2_Ns[:, 0]), x2_Ns[:, 1], maxfev=10000, p0 = [-6, 0, 5, 7])
popt_v, pcov_v = curve_fit(f, np.log2(v_Ns[:, 0]), v_Ns[:, 1])
popt_k, pcov_k = curve_fit(f, np.log2(k_Ns[:, 0]), k_Ns[:, 1])

x2_Ns_Warm = []
v_Ns_Warm = []
k_Ns_Warm = []

mask_warm = "_Warm_m=" + GetStr(m) + "_alpha=" + GetStr(alpha) + "_N=" + str(N) + "_Ns="
Ns_set = [2 ** i for i in range(int(np.log2(Ns_max)) + 1)]

for Ns in Ns_set:
    paths = []
    x2 = []
    v = []
    k = []
    for rank in range(Number_of_cores):
        file = open("Data/" + str(rank) + mask_warm + str(Ns) + ".dat", "r")
        data = file.readlines()
        for line in data:
            path = np.array(list(map(float, line.split()))).reshape(N, d)
            paths.append(path)
        file.close()
    for path in paths:
        x2.append(GetX2(path))
        v.append(GetV(path))
        k.append(GetK(path))
    x2_Ns_Warm.append([Ns, np.mean(x2), np.std(x2) / ((N - 1) ** 0.5)])
    v_Ns_Warm.append([Ns, np.mean(v), np.std(v) / ((N - 1) ** 0.5)])
    k_Ns_Warm.append([Ns, np.mean(k), np.std(k) / ((N - 1) ** 0.5)]) 

x2_Ns_Warm = np.array(x2_Ns_Warm)
v_Ns_Warm = np.array(v_Ns_Warm)
k_Ns_Warm = np.array(k_Ns_Warm)

print("\nx2\n")
print(x2_Ns.tolist())
print("\nFit parameters\n")
print(popt_x2.tolist())
print("\nFit covariance\n")
print(np.diag(pcov_x2).tolist())
plt.errorbar(x = np.log2(x2_Ns[:, 0]), y = x2_Ns[:, 1], yerr = x2_Ns[:, 2], fmt = "bo", label = r"Thermalization of $\langle q^2 \rangle$")
plt.plot(np.log2(x2_Ns[:, 0]), f(np.log2(x2_Ns[:, 0]), *popt_x2), 'k--',
         label=r'Fit: A=%5.3f, B=%5.6f, C=%5.3f, D=%5.3f' % tuple(popt_x2))
plt.errorbar(x = np.log2(x2_Ns_Warm[:, 0]), y = x2_Ns_Warm[:, 1], yerr = x2_Ns_Warm[:, 2], fmt = "ro", label = r"Warm thermalization of $\langle q^2 \rangle$")
plt.title(r"m = " + str(m) + r", $\alpha = $" + str(alpha) + r", $N = $" + str(N) + r", $\beta = $" + str(beta))
plt.xlabel(r"$log_2 N_s$")
plt.ylabel(r"$\langle x^2 \rangle$")
plt.legend()
plt.show()

print("\nV\n")
print(v_Ns.tolist())
print("\nFit parameters\n")
print(popt_v.tolist())
print("\nFit covariance\n")
print(np.diag(pcov_v).tolist())
plt.errorbar(x = np.log2(v_Ns[:, 0]), y = v_Ns[:, 1], yerr = v_Ns[:, 2], fmt = "bo", label = "Холодный старт")
#plt.plot(np.log2(v_Ns[:, 0]), f(np.log2(v_Ns[:, 0]), *popt_v), 'k--',
#         label=r'Fit: A=%5.3f, B=%5.6f, C=%5.3f, D=%5.3f' % tuple(popt_v))
plt.errorbar(x = np.log2(v_Ns_Warm[:, 0]), y = v_Ns_Warm[:, 1], yerr = v_Ns_Warm[:, 2], fmt = "ro", label = "Старт с данных нейросети")
plt.hlines(-0.25, 0, 18, color = "green", label = "Непрерывный предел")
plt.title(r"$\alpha = $" + str(alpha) + r", $N = $" + str(N) + r", $\beta = $" + str(beta))
plt.xlabel(r"$log_2 N_s$")
plt.ylabel(r"$\langle V(x) \rangle$")
plt.legend()
plt.show()

print("\nK\n")
print(k_Ns.tolist())
print("\nFit parameters\n")
print(popt_k.tolist())
print("\nFit covariance\n")
print(np.diag(pcov_k).tolist())
plt.errorbar(x = np.log2(k_Ns[:, 0]), y = k_Ns[:, 1], yerr = k_Ns[:, 2], fmt = "bo", label = "Холодный старт")
#plt.plot(np.log2(k_Ns[:, 0]), f(np.log2(k_Ns[:, 0]), *popt_k), 'k--',
#         label=r'Fit: A=%5.3f, B=%5.6f, C=%5.3f, D=%5.3f' % tuple(popt_k))
plt.errorbar(x = np.log2(k_Ns_Warm[:, 0]), y = k_Ns_Warm[:, 1], yerr = k_Ns_Warm[:, 2], fmt = "ro", label = "Старт с данных нейросети")
plt.hlines(0.125, 0, 18, color = "green", label = "Непрерывный предел")
plt.title(r"$\alpha = $" + str(alpha) + r", $N = $" + str(N) + r", $\beta = $" + str(beta))
plt.xlabel(r"$log_2 N_s$")
plt.ylabel(r"$\langle K(p) \rangle$")
plt.legend()
plt.show()
# Out:
# /var/folders/sf/z2_k64nn16l9x71mf6mwhs6h0000gn/T/ipykernel_50887/1926970843.py:16: RuntimeWarning: divide by zero encountered in power
#   return a * np.exp(-b * x ** c) + d
# x2
#
# [[1.0, 0.04817194084832866, 0.00040016196882036096], [2.0, 0.0806565390278301, 0.000591325795851497], [4.0, 0.1237600307819171, 0.0010112445086465222], [8.0, 0.1772098408510111, 0.001608437243542808], [16.0, 0.24119661945097742, 0.002574611326685404], [32.0, 0.3137318023600964, 0.004145226197461722], [64.0, 0.40701584684662645, 0.0067290289101986115], [128.0, 0.5766746242347265, 0.012324701325814836], [256.0, 0.8399986545840515, 0.021284924049110053], [512.0, 1.2513866682074855, 0.038041151202575], [1024.0, 1.6672961522432552, 0.055107627482743074], [2048.0, 2.250197740404288, 0.0961041028006541], [4096.0, 2.634826293229763, 0.12529267229395163], [8192.0, 2.992678782696457, 0.18233156774897885], [16384.0, 3.1146738299218684, 0.1789455828959149], [32768.0, 3.302523513415235, 0.27324627551707203], [65536.0, 3.7152923789370527, 0.5402651024832708], [131072.0, 4.045907007946742, 0.5156583459758615]]
#
# Fit parameters
#
# [-3.9852897024401592, 0.00022563108382080466, 3.3539047620901417, 4.07387704049542]
#
# Fit covariance
#
# [0.04131216307893282, 1.8202458243550596e-08, 0.0703111250193074, 0.033112729831596605]
# V
#
# [[1.0, -0.4724796449765338, 0.000319282979229295], [2.0, -0.45311459692866707, 0.0005365705340374787], [4.0, -0.4249334270650634, 0.0009640441123120334], [8.0, -0.3878529887660182, 0.0017756651703072191], [16.0, -0.3494708506788538, 0.0027233492629735825], [32.0, -0.32372955020483013, 0.0031998396222963767], [64.0, -0.31616334312819866, 0.0031336504765633435], [128.0, -0.32714416293534593, 0.002702196127477701], [256.0, -0.3150293732872191, 0.002564420455607494], [512.0, -0.302140518082226, 0.0026276530576147014], [1024.0, -0.2864656794813966, 0.002734215303015211], [2048.0, -0.2685911932849202, 0.0031050336679092605], [4096.0, -0.263687166677038, 0.0033726434992902396], [8192.0, -0.2558733350526953, 0.0036611765885636322], [16384.0, -0.2516290909002682, 0.0039017921830124995], [32768.0, -0.2500724203704177, 0.004040130675301228], [65536.0, -0.2496902359734723, 0.004051185891019708], [131072.0, -0.24552218646530966, 0.004216698497266131]]
#
# Fit parameters
#
# [-0.24962968731382326, 0.14812400689121585, 1.0264209217432727, -0.22892427398461224]
#
# Fit covariance
#
# [0.00058028901711016, 0.0011306683493050357, 0.02381346147286705, 0.00035171566362103985]
# K
#
# [[1.0, 1.8654334313202585, 0.01512810099649302], [2.0, 1.1644450993235813, 0.017237737177410485], [4.0, 0.7240825085155534, 0.020284579221390892], [8.0, 0.5319646589437695, 0.02012838768384936], [16.0, 0.4211359933034573, 0.020104204633304663], [32.0, 0.3442324820526427, 0.021044661593244987], [64.0, 0.31922136384130184, 0.021620268508114732], [128.0, 0.2781874838022213, 0.02092460890415814], [256.0, 0.22564308506593186, 0.02163430279911887], [512.0, 0.21309864561343675, 0.02006265262870655], [1024.0, 0.15524378973469033, 0.021920707070765412], [2048.0, 0.11285873725570576, 0.022714506237117925], [4096.0, 0.13375132981297658, 0.021835350205549265], [8192.0, 0.11728174235783337, 0.020906578234277936], [16384.0, 0.127811726714597, 0.020756671223046894], [32768.0, 0.09636923771359887, 0.02330598333557452], [65536.0, 0.12931606110155816, 0.02146361008042899], [131072.0, 0.13067476519809157, 0.022107309362763745]]
#
# Fit parameters
#
# [1.7615319838523156, 0.5645464978299441, 0.7933808130618606, 0.1109195894325394]
#
# Fit covariance
#
# [0.001373990294079062, 0.000858710691557334, 0.0021089531107551162, 0.0002876013217310651]

# %%
from scipy.special import gamma
import numpy as np

xmax = 20
delta = 0.05
rho = [0 for i in range(2 * int(xmax / delta) + 1)]
rho_warm = [0 for i in range(2 * int(xmax / delta) + 1)]
x = [i * delta - xmax for i in range(len(rho))]
y = []

for point in x:
    y.append(
        2 ** (2 / alpha - 1) * (2 - alpha) / alpha ** (2 / alpha - 1) / gamma(2 / alpha) * np.exp(-2 / alpha * np.exp(-alpha * point) - (2 - alpha) * point)
    )

for core in range(Number_of_cores):
    file = open("Data/" + str(core) + mask + str(Ns_max) + ".dat", "r")
    data = file.readlines()
    for line in data:
        path = np.array(list(map(float, line.split()))).reshape(N, d)
        for point in path:
            index = int((xmax + point) / delta)
            rho[index] += 1 / (Number_of_cores * len(data) * len(path) * delta)

for core in range(Number_of_cores):
    file = open("Data/" + str(core) + mask_warm + str(Ns_max) + ".dat", "r") # Указать количество свипов
    data = file.readlines()
    for line in data:
        path = np.array(list(map(float, line.split()))).reshape(N, d)
        for point in path:
            index = int((xmax + point) / delta)
            rho_warm[index] += 1 / (Number_of_cores * len(data) * len(path) * delta)
            
plt.plot(x, rho, "b.", label = "Холодный старт")
plt.plot(x, rho_warm, "r.", label = "Данные нейросети")
plt.plot(x, y, "g-", label = "Непрерывный предел")
plt.title(r"$\alpha = $" + str(alpha) + r", $N = $" + str(N) + r", $\beta = $" + str(beta))
plt.xlabel(r"$x$")
plt.ylabel(r"$|\psi (x)|^2$")
plt.xlim(-5, 15)
plt.legend()
plt.show()
